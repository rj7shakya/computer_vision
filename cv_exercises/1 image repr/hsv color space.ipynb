# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# %matplotlib inline 
image = cv2.imread('images/water_balloons.jpg')
image_copy = np.copy(image)
image = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
#rgb channels 
r=image[:,:,0]
g=image[:,:,1]
b=image[:,:,2]
f,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,10))
ax1.imshow(r,cmap='gray')
ax2.imshow(g,cmap='gray')
ax3.imshow(b,cmap='gray')

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_RGB2HSV)
h=hsv[:,:,0]
s=hsv[:,:,1]
v=hsv[:,:,2]
f,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(20,10))
ax1.imshow(h,cmap='gray')
ax2.imshow(s,cmap='gray')
ax3.imshow(v,cmap='gray')

# %%
lower_hue = np.array([160,0,0]) 
upper_hue = np.array([180,255,255])

lower_pink = np.array([180,0,100]) 
upper_pink = np.array([255,255,230])

# %%
masked_rgb = cv2.inRange(image,lower_pink,upper_pink)
masked_image = np.copy(image)
masked_image[masked_rgb==0]=[0,0,0]
plt.imshow(masked_image)

# %%
masked_hsv = cv2.inRange(hsv,lower_hue,upper_hue)
masked_image = np.copy(image)
masked_image[masked_hsv==0]=[0,0,0]
plt.imshow(masked_image)
